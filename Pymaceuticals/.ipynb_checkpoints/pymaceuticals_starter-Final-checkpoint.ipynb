# %% [markdown]
# ## Observations and Insights
# ### 1. There is a positive correlation between the average tumor volume and the weight of the mice.
# ### 2. Ramicane and Capomulin were the most used treatments out of the 10.
# ### 3. Ramicane and Capomulin also had the best final tumor volumes among the 4 treatments.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from scipy.stats import linregress

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single dataset
merged_df = pd.merge(mouse_metadata, study_results, on="Mouse ID", how="left")
merged_df

# Display the data table for preview
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice.
num_mice = len((merged_df["Mouse ID"]).unique())
print(num_mice)
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html
#merged_df.drop_duplicates(subset=['Mouse ID','Timepoint'])
duplicate_id = merged_df.loc[merged_df.duplicated(subset=['Mouse ID','Timepoint']),'Mouse ID'].unique()
print(duplicate_id)
# Out:
# ['g989']

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mouse = merged_df.loc[merged_df["Mouse ID"] == 'g989']
duplicate_mouse
# Out:
#     Mouse ID Drug Regimen     Sex  Age_months  Weight (g)  Timepoint  \
# 908     g989     Propriva  Female          21          26          0
# 909     g989     Propriva  Female          21          26          0
# 910     g989     Propriva  Female          21          26          5
# 911     g989     Propriva  Female          21          26          5
# 912     g989     Propriva  Female          21          26         10
# 913     g989     Propriva  Female          21          26         10
# 914     g989     Propriva  Female          21          26         15
# 915     g989     Propriva  Female          21          26         15
# 916     g989     Propriva  Female          21          26         20
# 917     g989     Propriva  Female          21          26         20
# 918     g989     Propriva  Female          21          26         25
# 919     g989     Propriva  Female          21          26         30
# 920     g989     Propriva  Female          21          26         35
#
# ...

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
#clean_data = merged_df[merged_df['Mouse ID'].isin(duplicate_mouse)== False]
clean_data = merged_df.drop_duplicates(subset=['Mouse ID','Timepoint'], keep ='first')
clean_data
# Out:
#      Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0        k403     Ramicane  Male          21          16          0
# 1        k403     Ramicane  Male          21          16          5
# 2        k403     Ramicane  Male          21          16         10
# 3        k403     Ramicane  Male          21          16         15
# 4        k403     Ramicane  Male          21          16         20
# ...       ...          ...   ...         ...         ...        ...
# 1888     z969     Naftisol  Male           9          30         25
# 1889     z969     Naftisol  Male           9          30         30
# 1890     z969     Naftisol  Male           9          30         35
# 1891     z969     Naftisol  Male           9          30         40
# 1892     z969     Naftisol  Male           9          30         45
#
#       Tumor Volume (mm3)  Metastatic Sites
# 0              45.000000                 0
# 1              38.825898                 0
# ...

# %%
# Checking the number of mice in the clean DataFrame.
num_mice_clean = len((clean_data["Mouse ID"]).unique())
num_mice_clean
# Out:
# 249

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
#summary["Mean"] = pd.DataFrame(merged_df.groupby(""))
mean_value = clean_data.groupby("Drug Regimen").mean()['Tumor Volume (mm3)']
median_value = clean_data.groupby("Drug Regimen").median()['Tumor Volume (mm3)']
var_value = clean_data.groupby("Drug Regimen").var()['Tumor Volume (mm3)']
std_value = clean_data.groupby("Drug Regimen").std()['Tumor Volume (mm3)']
sem_value = clean_data.groupby("Drug Regimen").sem()['Tumor Volume (mm3)']

summary = pd.DataFrame({"Mean of Tumor Volume":mean_value,
                        "Median of Tumor Volume":median_value,
                        "Variance of Tumor Volume":var_value,
                        "Standard Deviation of Tumor Volume":std_value,
                        "SEM of Tumor Volume":sem_value
                           
})
summary
# This method is the most straighforward, creating multiple series and putting them all together at the end.
# Out:
#               Mean of Tumor Volume  Median of Tumor Volume  \
# Drug Regimen
# Capomulin                40.675741               41.557809
# Ceftamin                 52.591172               51.776157
# Infubinol                52.884795               51.820584
# Ketapril                 55.235638               53.698743
# Naftisol                 54.331565               52.509285
# Placebo                  54.033581               52.288934
# Propriva                 52.393463               50.909965
# Ramicane                 40.216745               40.673236
# Stelasyn                 54.233149               52.431737
# Zoniferol                53.236507               51.818479
#
#               Variance of Tumor Volume  Standard Deviation of Tumor Volume  \
# Drug Regimen
# Capomulin                    24.947764                            4.994774
# Ceftamin                     39.290177                            6.268188
# ...

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# df.agg()
summary2 = clean_data.groupby("Drug Regimen").agg({'Tumor Volume (mm3)':["mean","median","var","std","sem"]})
summary2
# This method produces everything in a single groupby function
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.393463  50.909965  43.138803  6.568014  0.525862
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pandas. 
mice_count = clean_data["Drug Regimen"].value_counts()
mice_count.plot(kind = 'bar')
plt.title("Total Mice by Treatment")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice")
plt.show()

# %%
# Generate a bar plot showing the total number of mice for each treatment throughout the course of the study using pyplot.
mice_count
x_axis = mice_count.index.values
y_axis = mice_count.values
plt.bar(x_axis,y_axis,align="center")
plt.xticks(rotation = 90)
plt.title("Total Mice by Treatment")
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
gender = clean_data["Sex"].value_counts()
gender.plot(kind="pie", autopct= '%1.1f%%')
plt.title("Male and Female Mice")
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(gender,labels=["Male","Female"],autopct="%1.1f%%")
plt.ylabel("Sex")
plt.title("Male and Female Mice")
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Merge this group df with the original dataframe to get the tumor volume at the last timepoint
# Start by getting the last (greatest) timepoint for each mouse

cap_df = merged_df.loc[merged_df["Drug Regimen"] == "Capomulin",:]
ram_df = merged_df.loc[merged_df["Drug Regimen"] == "Ramicane", :]
inf_df = merged_df.loc[merged_df["Drug Regimen"] == "Infubinol", :]
ceft_df = merged_df.loc[merged_df["Drug Regimen"] == "Ceftamin", :]

caplast = cap_df.groupby('Mouse ID').max()['Timepoint']
ramlast = ram_df.groupby('Mouse ID').max()['Timepoint']
inflast = inf_df.groupby('Mouse ID').max()['Timepoint']
ceftlast = ceft_df.groupby('Mouse ID').max()['Timepoint']

caplastvol = pd.DataFrame(caplast)
caplastmerge = pd.merge(caplastvol, merged_df, on=("Mouse ID","Timepoint"),how="left")

ramlastvol = pd.DataFrame(ramlast)
ramlastmerge = pd.merge(ramlastvol, merged_df, on=("Mouse ID","Timepoint"),how="left")

inflastvol = pd.DataFrame(inflast)
inflastmerge = pd.merge(inflastvol, merged_df, on=("Mouse ID","Timepoint"),how="left")

ceftlastvol = pd.DataFrame(ceftlast)
ceftlastmerge = pd.merge(ceftlastvol, merged_df, on=("Mouse ID","Timepoint"),how="left")


cap_tumor = caplastmerge.max()["Tumor Volume (mm3)"]
ram_tumor = ramlastmerge.max()["Tumor Volume (mm3)"]
inf_tumor = inflastmerge.max()["Tumor Volume (mm3)"]
ceft_tumor = ceftlastmerge.max()["Tumor Volume (mm3)"]
print(f'The final tumor volume of Capomulin is {cap_tumor}.')
print(f'The final tumor volume of Ramicane is {ram_tumor}.')
print(f'The final tumor volume of Infubinol is {inf_tumor}.')
print(f'The final tumor volume of Ceftamin is {ceft_tumor}.')
# Out:
# The final tumor volume of Capomulin is 47.68596303.
# The final tumor volume of Ramicane is 45.22086888.
# The final tumor volume of Infubinol is 72.2267309.
# The final tumor volume of Ceftamin is 68.92318457.

# %%
# Put treatments into a list for for loop (and later for plot labels)
treat_list = ['Capomulin', 'Ramicane', 'Infubinol','Ceftamin']

# Create empty list to fill with tumor vol data (for plotting)
tumor_vol = []

# Calculate the IQR and quantitatively determine if there are any potential outliers. 
captumor = caplastmerge["Tumor Volume (mm3)"]

quartiles = captumor.quantile([.25,.5,.75])
caplowerq = quartiles[0.25]
capupperq = quartiles[0.75]
iqr = capupperq-caplowerq
caplower_bound = caplowerq - (1.5*iqr)
capupper_bound = capupperq + (1.5*iqr)

ramtumor = ramlastmerge["Tumor Volume (mm3)"]

quartiles = ramtumor.quantile([.25,.5,.75])
ramlowerq = quartiles[0.25]
ramupperq = quartiles[0.75]
iqr = ramupperq-ramlowerq
ramlower_bound = ramlowerq - (1.5*iqr)
ramupper_bound = ramupperq + (1.5*iqr)

inftumor = inflastmerge["Tumor Volume (mm3)"]

quartiles = inftumor.quantile([.25,.5,.75])
inflowerq = quartiles[0.25]
infupperq = quartiles[0.75]
iqr = infupperq-inflowerq
inflower_bound = inflowerq - (1.5*iqr)
infupper_bound = infupperq + (1.5*iqr)

cefttumor = ceftlastmerge["Tumor Volume (mm3)"]

quartiles = cefttumor.quantile([.25,.5,.75])
ceftlowerq = quartiles[0.25]
ceftupperq = quartiles[0.75]
iqr = ceftupperq-ceftlowerq
ceftlower_bound = ceftlowerq - (1.5*iqr)
ceftupper_bound = ceftupperq + (1.5*iqr)

    # Locate the rows which contain mice on each drug and get the tumor volumes # add subset 
#tumor_vol_df = merged_df.loc[:, ["Mouse ID","Drug Regimen","Tumor Volume (mm3)"]]
#tumor_vol_df 
  
    
    # Determine outliers using upper and lower bounds
print(f"Capomulin potential outliers could be values below {caplower_bound} and above {capupper_bound}.")
print(f"Ramicane potential outliers could be values below {ramlower_bound} and above {ramupper_bound}.")
print(f"Infubinol potential outliers could be values below {inflower_bound} and above {infupper_bound}.")
print(f"Ceftamin potential outliers could be values below {ceftlower_bound} and above {ceftupper_bound}.")
# Out:
# Capomulin potential outliers could be values below 20.70456164999999 and above 51.83201549.
# Ramicane potential outliers could be values below 17.912664470000003 and above 54.30681135.
# Infubinol potential outliers could be values below 36.83290494999999 and above 82.74144559000001.
# Ceftamin potential outliers could be values below 25.355449580000002 and above 87.66645829999999.

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
tumor_vol = [captumor, ramtumor, inftumor, cefttumor]

fig1, ax1 = plt.subplots()
ax1.set_title('Tumors')
ax1.set_ylabel('Final Tumor Volume (mm3)')
ax1.set_xlabel('Drug Regimen')

ax1.boxplot(tumor_vol, labels=treat_list)

plt.show()

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
#https://www.geeksforgeeks.org/how-to-randomly-select-rows-from-pandas-dataframe/
#randomly chose a mouse in capomulin dataframe
cap_df.sample()

timevtumor = merged_df[merged_df["Mouse ID"].isin(["w914"])]
timevtumor

timevtumor_data = timevtumor[["Mouse ID", "Timepoint", "Tumor Volume (mm3)"]]
timevtumor_data

line_plot_df = timevtumor_data.reset_index()
line_plot_df

line_plot_final = line_plot_df[["Mouse ID", "Timepoint", "Tumor Volume (mm3)"]]
line_plot_final

lines = line_plot_final.plot.line()
plt.title("Timepoint vs. Tumor Volume")
plt.xlabel("Tumor Volume")
plt.ylabel("Time")
plt.show()

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
capavgvol = cap_df.groupby(['Mouse ID']).mean()
plt.scatter(capavgvol['Weight (g)'],capavgvol['Tumor Volume (mm3)'])
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.title('Mouse Weight vs. Average Tumor Volume')

plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen
#regression.ipynb lesson & correlation.ipynb 
x_values = capavgvol['Weight (g)']
y_values = capavgvol['Tumor Volume (mm3)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.title('Mouse Weight vs. Average Tumor Volume')
weight = merged_df.iloc[:,4]
avgtumorvol =merged_df.iloc[:,6]
correlation = st.pearsonr(weight,avgtumorvol)
print(f"The correlation between weight and average tumor volume is {round(correlation[0],2)}")
plt.show()
# Out:
# The correlation between weight and average tumor volume is 0.59
